# %%
# !pwd
# Out:
# /home/nicksung/Desktop/nicksung/bwb_full_v2

# %%
#!/usr/bin/env python3
import os
import torch
import numpy as np
import pandas as pd
from torch.utils.data import DataLoader
import vtk

from dataset_v2 import UnifiedDesignDataset, design_collate_fn
from film_model_v1 import FiLMNet

# ——— Paths ———
trainval_csv     = "./processed/final_data_train_val.csv"
trainval_pts_h5  = "/home/nicksung/Desktop/nicksung/bwb_full/surface_point/surface_data_train_val.hdf5"
trainval_norm_h5 = "/home/nicksung/Desktop/nicksung/bwb_full/surface_point/normals_data_train_val.hdf5"

test_csv         = "/home/nicksung/Desktop/nicksung/bwb_full/processed/final_data_test.csv"
test_pts_h5      = "/home/nicksung/Desktop/nicksung/bwb_full/surface_point/surface_data_test.hdf5"
test_norm_h5     = "/home/nicksung/Desktop/nicksung/bwb_full/surface_point/normals_data_test.hdf5"

model_path       = "./film_model_saved_weights/final_model_v1.pth"
bestpred_npy     = "/home/nicksung/Desktop/nicksung/bwb_full/point_to_parameter/best_predictions.npy"

original_vtk_dir = "/home/nicksung/Desktop/nicksung/bwb_full/data_test"
vtk_out_dir      = "./vtk_pred_param"
os.makedirs(vtk_out_dir, exist_ok=True)

batch_size = 64
device     = "cuda" if torch.cuda.is_available() else "cpu"

# ——— Load best‐predicted shape parameters ———
bestpred_array = np.load(bestpred_npy)  # shape (N_geoms, 9)

# -----------------------------------------------------------------------------
# Unnormalize helper
# -----------------------------------------------------------------------------
def unnormalize_coeffs(coeffs_norm, dataset):
    cp  = coeffs_norm[:,0]*dataset.output_std[0] + dataset.output_mean[0]
    cfx = coeffs_norm[:,1]*dataset.output_std[1] + dataset.output_mean[1]
    cfz = coeffs_norm[:,2]*dataset.output_std[2] + dataset.output_mean[2]
    return np.column_stack([cp,cfx,cfz])

# -----------------------------------------------------------------------------
# Metric computation
# -----------------------------------------------------------------------------
def compute_test_metrics_from_loader(model, loader, dataset, device='cuda'):
    model.eval()
    sse = np.zeros(3); sae = np.zeros(3)
    sum_gt_abs = np.zeros(3); sum_gt_sq = np.zeros(3)
    total=0
    with torch.no_grad():
        for coords,conds,targets in loader:
            coords,conds,targets = coords.float().to(device), conds.float().to(device), targets.float().to(device)
            preds = model(coords,conds)
            p_np, t_np = preds.cpu().numpy(), targets.cpu().numpy()
            p_u = unnormalize_coeffs(p_np, dataset)
            t_u = unnormalize_coeffs(t_np, dataset)
            diff = p_u - t_u
            sse        += np.sum(diff**2,axis=0)
            sae        += np.sum(np.abs(diff),axis=0)
            sum_gt_abs += np.sum(np.abs(t_u),axis=0)
            sum_gt_sq  += np.sum(t_u**2,    axis=0)
            total     += t_u.shape[0]
    mse    = sse/total; mae = sae/total
    eps = 1e-20
    rel_l1 = sae/(sum_gt_abs+eps); rel_l2 = sse/(sum_gt_sq+eps)
    keys=["cp","cf_x","cf_z"]
    return dict(zip(keys,mse)), dict(zip(keys,mae)), dict(zip(keys,rel_l1)), dict(zip(keys,rel_l2))

# -----------------------------------------------------------------------------
# Model loader
# -----------------------------------------------------------------------------
def load_trained_model(model_path, device='cuda'):
    model = FiLMNet(13,6,3,256,4,3)
    sd = torch.load(model_path,map_location=device)
    model.load_state_dict(sd)
    model.to(device).eval()
    return model

# -----------------------------------------------------------------------------
# VTK I/O
# -----------------------------------------------------------------------------
def read_original_mesh(fn):
    if not os.path.isfile(fn): return None,None
    r=vtk.vtkPolyDataReader(); r.SetFileName(fn); r.Update()
    pd_ = r.GetOutput()
    if pd_.GetNumberOfPoints()==0: return None,None
    pts = np.array([pd_.GetPoint(i) for i in range(pd_.GetNumberOfPoints())],dtype=np.float32)
    polys = pd_.GetPolys()
    return pts, polys

def write_vtk_with_mesh(coords,polys,gt,true_p,best_p,fn):
    n=coords.shape[0]
    pts=vtk.vtkPoints(); pts.SetNumberOfPoints(n)
    for i,(x,y,z) in enumerate(coords): pts.SetPoint(i,float(x),float(y),float(z))
    pd_ = vtk.vtkPolyData(); pd_.SetPoints(pts); pd_.SetPolys(polys)
    for name,idx in zip(["cp","cf_x","cf_z"], range(3)):
        gt_arr   = gt[:,idx]
        t_arr    = true_p[:,idx]
        b_arr    = best_p[:,idx]
        err_t    = np.abs(gt_arr - t_arr)
        err_b    = np.abs(gt_arr - b_arr)
        for arr,sfx in [(gt_arr,"ground_truth"),
                        (t_arr,"pred_true"),
                        (err_t,"err_true"),
                        (b_arr,"pred_best"),
                        (err_b,"err_best")]:
            fa=vtk.vtkFloatArray(); fa.SetName(f"{name}_{sfx}")
            fa.SetNumberOfComponents(1); fa.SetNumberOfValues(n)
            for j,v in enumerate(arr): fa.SetValue(j,float(v))
            pd_.GetPointData().AddArray(fa)
    w=vtk.vtkPolyDataWriter(); w.SetFileName(fn); w.SetInputData(pd_); w.Write()
    print(f"Wrote {fn}")

# -----------------------------------------------------------------------------
# Main
# -----------------------------------------------------------------------------
if __name__=="__main__":
    # 1) Norm stats from train+val
    trainval_ds = UnifiedDesignDataset(trainval_csv,
                                       trainval_pts_h5,
                                       trainval_norm_h5,
                                       mode="train")
    norm_stats = trainval_ds.norm_stats
    print("Norm stats:",norm_stats)

    # 2) Test set
    test_ds = UnifiedDesignDataset(test_csv,
                                   test_pts_h5,
                                   test_norm_h5,
                                   norm_stats=norm_stats,
                                   mode="test")
    print("Test designs:",len(test_ds))

    # 3) Metrics TRUE shape
    loader = DataLoader(test_ds,batch_size=batch_size,
                        collate_fn=design_collate_fn,shuffle=False)
    model  = load_trained_model(model_path,device=device)
    mse_t,mae_t,r1_t,r2_t = compute_test_metrics_from_loader(model,loader,test_ds,device)
    print("\n=== TRUE shape metrics ===")
    for d in ["cp","cf_x","cf_z"]:
        print(f"{d}: MSE={mse_t[d]:.6e}, MAE={mae_t[d]:.6e}, RelL1={r1_t[d]:.6e}, RelL2={r2_t[d]:.6e}")

    # 4) Inject bestpred into each design_item via enumerate → geom_idx
    for geom_idx, design_item in enumerate(test_ds.design_info):
        for case in design_item:
            # stash original
            case['flight_cond_true'] = case['flight_cond'].copy()
            # pull bestpred
            shape_pred = bestpred_array[geom_idx]  # safe lookup 0…N-1
            # normalize shape_pred
            shp_n = (shape_pred - trainval_ds.shape_mean)/trainval_ds.shape_std
            fl_np = case['flight_cond_true'][:4]
            case['flight_cond'] = np.concatenate([fl_np, shp_n],axis=0)

    # 5) Metrics BEST shape
    mse_b, mae_b, r1_b, r2_b = compute_test_metrics_from_loader(model,loader,test_ds,device)
    print("\n=== BEST shape metrics ===")
    for d in ["cp","cf_x","cf_z"]:
        print(f"{d}: MSE={mse_b[d]:.6e}, MAE={mae_b[d]:.6e}, RelL1={r1_b[d]:.6e}, RelL2={r2_b[d]:.6e}")

    # 6) Export comparison VTKs
    for geom_idx, design_item in enumerate(test_ds.design_info):
        for case in design_item:
            pts6   = case['points']
            tgt    = case['coeffs']
            flt_t  = case['flight_cond_true']
            flt_b  = case['flight_cond']
            N = pts6.shape[0]
            coords = pts6[:,:3]   # mesh coords
            normals= pts6[:,3:]   # normals (not used in mesh write)
            # predict true
            ct = torch.from_numpy(flt_t).float().unsqueeze(0).expand(N,-1).to(device)
            x  = torch.from_numpy(pts6).float().to(device)
            with torch.no_grad(): p_t = model(x,ct).cpu().numpy()
            # predict best
            cb = torch.from_numpy(flt_b).float().unsqueeze(0).expand(N,-1).to(device)
            with torch.no_grad(): p_b = model(x,cb).cpu().numpy()
            # unnorm
            gt_u   = unnormalize_coeffs(case['coeffs'],test_ds)
            t_u    = unnormalize_coeffs(p_t,       test_ds)
            b_u    = unnormalize_coeffs(p_b,       test_ds)
            # mesh io
            mesh_fn = os.path.join(original_vtk_dir,f"{case['case_name']}.vtk")
            mpts,polys = read_original_mesh(mesh_fn)
            if mpts is None: continue
            out_fn = os.path.join(vtk_out_dir, f"{case['case_name']}_cmp.vtk")
            write_vtk_with_mesh(mpts,polys,gt_u,t_u,b_u,out_fn)

    print("\nDone. Comparison VTKs in", vtk_out_dir)
# Out:
# Unique geometries in CSV: 999
# Unique geometries in dataset after HDF5 filtering: 999
# Norm stats: {'shape_mean': array([149.73118913, 124.91552208, 445.6917667 , 699.66621744,
#        230.41100793,  75.01262061,  49.9939966 ,  49.98475764,
#         31.92120612]), 'shape_std': array([ 28.91160165,  43.30243653, 144.01147529,  86.77421237,
#         28.92184576,   8.65547754,   5.77840385,   5.78463163,
#          4.61681044]), 'flight_mean': array([2.02570334e+01, 1.74719006e+07, 2.66649940e-01, 4.93905060e+00]), 'flight_std': array([1.15438056e+01, 1.61492810e+07, 1.29571841e-01, 8.63705480e+00]), 'coord_min': array([-7.14891175e-17, -1.05967498e+00, -9.10214633e-02]), 'coord_max': array([1.16249204, 1.05967498, 0.09102037]), 'output_mean': array([-0.10253485,  0.0074317 ,  0.00028973]), 'output_std': array([0.45806409, 0.02630924, 0.01266003])}
# Unique geometries in CSV: 100
# Unique geometries in dataset after HDF5 filtering: 100
# Test designs: 100
#
# === TRUE shape metrics ===
# cp: MSE=7.867552e-03, MAE=3.720478e-02, RelL1=1.352403e-01, RelL2=3.116076e-02
# cf_x: MSE=2.804882e-05, MAE=1.347295e-03, RelL1=2.208660e-01, RelL2=7.735941e-02
# cf_z: MSE=1.508278e-05, MAE=7.964935e-04, RelL1=3.001249e-01, RelL2=1.879010e-01
#
# === BEST shape metrics ===
# cp: MSE=1.186639e-02, MAE=4.332644e-02, RelL1=1.499411e-01, RelL2=4.236460e-02
# cf_x: MSE=1.815303e-04, MAE=1.980386e-03, RelL1=2.403015e-01, RelL2=1.677897e-01
# cf_z: MSE=5.720031e-05, MAE=1.192382e-03, RelL1=3.152521e-01, RelL2=2.183707e-01
# Wrote ./vtk_pred_param/case_000_cmp.vtk
# Wrote ./vtk_pred_param/case_002_cmp.vtk
# Wrote ./vtk_pred_param/case_003_cmp.vtk
# Wrote ./vtk_pred_param/case_004_cmp.vtk
# Wrote ./vtk_pred_param/case_005_cmp.vtk
# Wrote ./vtk_pred_param/case_006_cmp.vtk
# Wrote ./vtk_pred_param/case_007_cmp.vtk
# Wrote ./vtk_pred_param/case_008_cmp.vtk
# Wrote ./vtk_pred_param/case_009_cmp.vtk
# Wrote ./vtk_pred_param/case_010_cmp.vtk
# Wrote ./vtk_pred_param/case_011_cmp.vtk
# Wrote ./vtk_pred_param/case_012_cmp.vtk
# Wrote ./vtk_pred_param/case_013_cmp.vtk
# Wrote ./vtk_pred_param/case_014_cmp.vtk
# Wrote ./vtk_pred_param/case_015_cmp.vtk
# Wrote ./vtk_pred_param/case_016_cmp.vtk
# Wrote ./vtk_pred_param/case_017_cmp.vtk
# Wrote ./vtk_pred_param/case_018_cmp.vtk
# Wrote ./vtk_pred_param/case_019_cmp.vtk
# Wrote ./vtk_pred_param/case_020_cmp.vtk
# Wrote ./vtk_pred_param/case_021_cmp.vtk
# Wrote ./vtk_pred_param/case_022_cmp.vtk
# Wrote ./vtk_pred_param/case_023_cmp.vtk
# Wrote ./vtk_pred_param/case_024_cmp.vtk
# Wrote ./vtk_pred_param/case_025_cmp.vtk
# Wrote ./vtk_pred_param/case_026_cmp.vtk
# Wrote ./vtk_pred_param/case_027_cmp.vtk
# Wrote ./vtk_pred_param/case_028_cmp.vtk
# Wrote ./vtk_pred_param/case_029_cmp.vtk
# Wrote ./vtk_pred_param/case_030_cmp.vtk
# Wrote ./vtk_pred_param/case_032_cmp.vtk
# Wrote ./vtk_pred_param/case_033_cmp.vtk
# Wrote ./vtk_pred_param/case_034_cmp.vtk
# Wrote ./vtk_pred_param/case_035_cmp.vtk
# Wrote ./vtk_pred_param/case_036_cmp.vtk
# Wrote ./vtk_pred_param/case_037_cmp.vtk
# Wrote ./vtk_pred_param/case_039_cmp.vtk
# Wrote ./vtk_pred_param/case_040_cmp.vtk
# Wrote ./vtk_pred_param/case_041_cmp.vtk
# Wrote ./vtk_pred_param/case_042_cmp.vtk
# Wrote ./vtk_pred_param/case_043_cmp.vtk
# Wrote ./vtk_pred_param/case_044_cmp.vtk
# Wrote ./vtk_pred_param/case_045_cmp.vtk
# Wrote ./vtk_pred_param/case_046_cmp.vtk
# Wrote ./vtk_pred_param/case_047_cmp.vtk
# Wrote ./vtk_pred_param/case_048_cmp.vtk
# Wrote ./vtk_pred_param/case_049_cmp.vtk
# Wrote ./vtk_pred_param/case_050_cmp.vtk
# Wrote ./vtk_pred_param/case_052_cmp.vtk
# Wrote ./vtk_pred_param/case_054_cmp.vtk
# Wrote ./vtk_pred_param/case_055_cmp.vtk
# Wrote ./vtk_pred_param/case_056_cmp.vtk
# Wrote ./vtk_pred_param/case_057_cmp.vtk
# Wrote ./vtk_pred_param/case_059_cmp.vtk
# Wrote ./vtk_pred_param/case_060_cmp.vtk
# Wrote ./vtk_pred_param/case_061_cmp.vtk
# Wrote ./vtk_pred_param/case_062_cmp.vtk
# Wrote ./vtk_pred_param/case_063_cmp.vtk
# Wrote ./vtk_pred_param/case_064_cmp.vtk
# Wrote ./vtk_pred_param/case_065_cmp.vtk
# Wrote ./vtk_pred_param/case_066_cmp.vtk
# Wrote ./vtk_pred_param/case_067_cmp.vtk
# Wrote ./vtk_pred_param/case_068_cmp.vtk
# Wrote ./vtk_pred_param/case_069_cmp.vtk
# Wrote ./vtk_pred_param/case_070_cmp.vtk
# Wrote ./vtk_pred_param/case_071_cmp.vtk
# Wrote ./vtk_pred_param/case_072_cmp.vtk
# Wrote ./vtk_pred_param/case_073_cmp.vtk
# Wrote ./vtk_pred_param/case_074_cmp.vtk
# Wrote ./vtk_pred_param/case_075_cmp.vtk
# Wrote ./vtk_pred_param/case_076_cmp.vtk
# Wrote ./vtk_pred_param/case_077_cmp.vtk
# Wrote ./vtk_pred_param/case_078_cmp.vtk
# Wrote ./vtk_pred_param/case_079_cmp.vtk
# Wrote ./vtk_pred_param/case_081_cmp.vtk
# Wrote ./vtk_pred_param/case_082_cmp.vtk
# Wrote ./vtk_pred_param/case_083_cmp.vtk
# Wrote ./vtk_pred_param/case_084_cmp.vtk
# Wrote ./vtk_pred_param/case_085_cmp.vtk
# Wrote ./vtk_pred_param/case_086_cmp.vtk
# Wrote ./vtk_pred_param/case_087_cmp.vtk
# Wrote ./vtk_pred_param/case_088_cmp.vtk
# Wrote ./vtk_pred_param/case_089_cmp.vtk
# Wrote ./vtk_pred_param/case_091_cmp.vtk
# Wrote ./vtk_pred_param/case_092_cmp.vtk
# Wrote ./vtk_pred_param/case_093_cmp.vtk
# Wrote ./vtk_pred_param/case_094_cmp.vtk
# Wrote ./vtk_pred_param/case_095_cmp.vtk
# Wrote ./vtk_pred_param/case_096_cmp.vtk
# Wrote ./vtk_pred_param/case_097_cmp.vtk
# Wrote ./vtk_pred_param/case_099_cmp.vtk
# Wrote ./vtk_pred_param/case_101_cmp.vtk
# Wrote ./vtk_pred_param/case_102_cmp.vtk
# Wrote ./vtk_pred_param/case_103_cmp.vtk
# Wrote ./vtk_pred_param/case_104_cmp.vtk
# Wrote ./vtk_pred_param/case_105_cmp.vtk
# Wrote ./vtk_pred_param/case_106_cmp.vtk
# Wrote ./vtk_pred_param/case_107_cmp.vtk
# Wrote ./vtk_pred_param/case_108_cmp.vtk
# Wrote ./vtk_pred_param/case_109_cmp.vtk
# Wrote ./vtk_pred_param/case_110_cmp.vtk
# Wrote ./vtk_pred_param/case_111_cmp.vtk
# Wrote ./vtk_pred_param/case_112_cmp.vtk
# Wrote ./vtk_pred_param/case_113_cmp.vtk
# Wrote ./vtk_pred_param/case_115_cmp.vtk
# Wrote ./vtk_pred_param/case_116_cmp.vtk
# Wrote ./vtk_pred_param/case_117_cmp.vtk
# Wrote ./vtk_pred_param/case_119_cmp.vtk
# Wrote ./vtk_pred_param/case_120_cmp.vtk
# Wrote ./vtk_pred_param/case_122_cmp.vtk
# Wrote ./vtk_pred_param/case_123_cmp.vtk
# Wrote ./vtk_pred_param/case_124_cmp.vtk
# Wrote ./vtk_pred_param/case_125_cmp.vtk
# Wrote ./vtk_pred_param/case_126_cmp.vtk
# Wrote ./vtk_pred_param/case_127_cmp.vtk
# Wrote ./vtk_pred_param/case_129_cmp.vtk
# Wrote ./vtk_pred_param/case_130_cmp.vtk
# Wrote ./vtk_pred_param/case_131_cmp.vtk
# Wrote ./vtk_pred_param/case_132_cmp.vtk
# Wrote ./vtk_pred_param/case_133_cmp.vtk
# Wrote ./vtk_pred_param/case_134_cmp.vtk
# Wrote ./vtk_pred_param/case_135_cmp.vtk
# Wrote ./vtk_pred_param/case_136_cmp.vtk
# Wrote ./vtk_pred_param/case_137_cmp.vtk
# Wrote ./vtk_pred_param/case_138_cmp.vtk
# Wrote ./vtk_pred_param/case_139_cmp.vtk
# Wrote ./vtk_pred_param/case_140_cmp.vtk
# Wrote ./vtk_pred_param/case_141_cmp.vtk
# Wrote ./vtk_pred_param/case_142_cmp.vtk
# Wrote ./vtk_pred_param/case_143_cmp.vtk
# Wrote ./vtk_pred_param/case_144_cmp.vtk
# Wrote ./vtk_pred_param/case_146_cmp.vtk
# Wrote ./vtk_pred_param/case_147_cmp.vtk
# Wrote ./vtk_pred_param/case_148_cmp.vtk
# Wrote ./vtk_pred_param/case_149_cmp.vtk
# Wrote ./vtk_pred_param/case_150_cmp.vtk
# Wrote ./vtk_pred_param/case_151_cmp.vtk
# Wrote ./vtk_pred_param/case_152_cmp.vtk
# Wrote ./vtk_pred_param/case_153_cmp.vtk
# Wrote ./vtk_pred_param/case_154_cmp.vtk
# Wrote ./vtk_pred_param/case_155_cmp.vtk
# Wrote ./vtk_pred_param/case_156_cmp.vtk
# Wrote ./vtk_pred_param/case_157_cmp.vtk
# Wrote ./vtk_pred_param/case_158_cmp.vtk
# Wrote ./vtk_pred_param/case_159_cmp.vtk
# Wrote ./vtk_pred_param/case_160_cmp.vtk
# Wrote ./vtk_pred_param/case_161_cmp.vtk
# Wrote ./vtk_pred_param/case_163_cmp.vtk
# Wrote ./vtk_pred_param/case_164_cmp.vtk
# Wrote ./vtk_pred_param/case_165_cmp.vtk
# Wrote ./vtk_pred_param/case_166_cmp.vtk
# Wrote ./vtk_pred_param/case_167_cmp.vtk
# Wrote ./vtk_pred_param/case_168_cmp.vtk
# Wrote ./vtk_pred_param/case_169_cmp.vtk
# Wrote ./vtk_pred_param/case_170_cmp.vtk
# Wrote ./vtk_pred_param/case_173_cmp.vtk
# Wrote ./vtk_pred_param/case_174_cmp.vtk
# Wrote ./vtk_pred_param/case_175_cmp.vtk
# Wrote ./vtk_pred_param/case_176_cmp.vtk
# Wrote ./vtk_pred_param/case_177_cmp.vtk
# Wrote ./vtk_pred_param/case_178_cmp.vtk
# Wrote ./vtk_pred_param/case_179_cmp.vtk
# Wrote ./vtk_pred_param/case_180_cmp.vtk
# Wrote ./vtk_pred_param/case_181_cmp.vtk
# Wrote ./vtk_pred_param/case_182_cmp.vtk
# Wrote ./vtk_pred_param/case_183_cmp.vtk
# Wrote ./vtk_pred_param/case_185_cmp.vtk
# Wrote ./vtk_pred_param/case_186_cmp.vtk
# Wrote ./vtk_pred_param/case_187_cmp.vtk
# Wrote ./vtk_pred_param/case_188_cmp.vtk
# Wrote ./vtk_pred_param/case_189_cmp.vtk
# Wrote ./vtk_pred_param/case_190_cmp.vtk
# Wrote ./vtk_pred_param/case_191_cmp.vtk
# Wrote ./vtk_pred_param/case_192_cmp.vtk
# Wrote ./vtk_pred_param/case_193_cmp.vtk
# Wrote ./vtk_pred_param/case_194_cmp.vtk
# Wrote ./vtk_pred_param/case_196_cmp.vtk
# Wrote ./vtk_pred_param/case_197_cmp.vtk
# Wrote ./vtk_pred_param/case_198_cmp.vtk
# Wrote ./vtk_pred_param/case_199_cmp.vtk
# Wrote ./vtk_pred_param/case_201_cmp.vtk
# Wrote ./vtk_pred_param/case_202_cmp.vtk
# Wrote ./vtk_pred_param/case_203_cmp.vtk
# Wrote ./vtk_pred_param/case_204_cmp.vtk
# Wrote ./vtk_pred_param/case_206_cmp.vtk
# Wrote ./vtk_pred_param/case_207_cmp.vtk
# Wrote ./vtk_pred_param/case_208_cmp.vtk
# Wrote ./vtk_pred_param/case_209_cmp.vtk
# Wrote ./vtk_pred_param/case_210_cmp.vtk
# Wrote ./vtk_pred_param/case_211_cmp.vtk
# Wrote ./vtk_pred_param/case_212_cmp.vtk
# Wrote ./vtk_pred_param/case_213_cmp.vtk
# Wrote ./vtk_pred_param/case_214_cmp.vtk
# Wrote ./vtk_pred_param/case_215_cmp.vtk
# Wrote ./vtk_pred_param/case_216_cmp.vtk
# Wrote ./vtk_pred_param/case_217_cmp.vtk
# Wrote ./vtk_pred_param/case_218_cmp.vtk
# Wrote ./vtk_pred_param/case_219_cmp.vtk
# Wrote ./vtk_pred_param/case_221_cmp.vtk
# Wrote ./vtk_pred_param/case_222_cmp.vtk
# Wrote ./vtk_pred_param/case_223_cmp.vtk
# Wrote ./vtk_pred_param/case_225_cmp.vtk
# Wrote ./vtk_pred_param/case_226_cmp.vtk
# Wrote ./vtk_pred_param/case_227_cmp.vtk
# Wrote ./vtk_pred_param/case_229_cmp.vtk
# Wrote ./vtk_pred_param/case_230_cmp.vtk
# Wrote ./vtk_pred_param/case_231_cmp.vtk
# Wrote ./vtk_pred_param/case_232_cmp.vtk
# Wrote ./vtk_pred_param/case_233_cmp.vtk
# Wrote ./vtk_pred_param/case_234_cmp.vtk
# Wrote ./vtk_pred_param/case_235_cmp.vtk
# Wrote ./vtk_pred_param/case_236_cmp.vtk
# Wrote ./vtk_pred_param/case_237_cmp.vtk
# Wrote ./vtk_pred_param/case_238_cmp.vtk
# Wrote ./vtk_pred_param/case_239_cmp.vtk
# Wrote ./vtk_pred_param/case_240_cmp.vtk
# Wrote ./vtk_pred_param/case_241_cmp.vtk
# Wrote ./vtk_pred_param/case_242_cmp.vtk
# Wrote ./vtk_pred_param/case_243_cmp.vtk
# Wrote ./vtk_pred_param/case_244_cmp.vtk
# Wrote ./vtk_pred_param/case_245_cmp.vtk
# Wrote ./vtk_pred_param/case_246_cmp.vtk
# Wrote ./vtk_pred_param/case_247_cmp.vtk
# Wrote ./vtk_pred_param/case_248_cmp.vtk
# Wrote ./vtk_pred_param/case_249_cmp.vtk
# Wrote ./vtk_pred_param/case_250_cmp.vtk
# Wrote ./vtk_pred_param/case_251_cmp.vtk
# Wrote ./vtk_pred_param/case_252_cmp.vtk
# Wrote ./vtk_pred_param/case_253_cmp.vtk
# Wrote ./vtk_pred_param/case_254_cmp.vtk
# Wrote ./vtk_pred_param/case_255_cmp.vtk
# Wrote ./vtk_pred_param/case_256_cmp.vtk
# Wrote ./vtk_pred_param/case_257_cmp.vtk
# Wrote ./vtk_pred_param/case_259_cmp.vtk
# Wrote ./vtk_pred_param/case_260_cmp.vtk
# Wrote ./vtk_pred_param/case_262_cmp.vtk
# Wrote ./vtk_pred_param/case_263_cmp.vtk
# Wrote ./vtk_pred_param/case_264_cmp.vtk
# Wrote ./vtk_pred_param/case_265_cmp.vtk
# Wrote ./vtk_pred_param/case_267_cmp.vtk
# Wrote ./vtk_pred_param/case_268_cmp.vtk
# Wrote ./vtk_pred_param/case_269_cmp.vtk
# Wrote ./vtk_pred_param/case_270_cmp.vtk
# Wrote ./vtk_pred_param/case_271_cmp.vtk
# Wrote ./vtk_pred_param/case_272_cmp.vtk
# Wrote ./vtk_pred_param/case_273_cmp.vtk
# Wrote ./vtk_pred_param/case_274_cmp.vtk
# Wrote ./vtk_pred_param/case_275_cmp.vtk
# Wrote ./vtk_pred_param/case_276_cmp.vtk
# Wrote ./vtk_pred_param/case_277_cmp.vtk
# Wrote ./vtk_pred_param/case_279_cmp.vtk
# Wrote ./vtk_pred_param/case_280_cmp.vtk
# Wrote ./vtk_pred_param/case_281_cmp.vtk
# Wrote ./vtk_pred_param/case_282_cmp.vtk
# Wrote ./vtk_pred_param/case_283_cmp.vtk
# Wrote ./vtk_pred_param/case_285_cmp.vtk
# Wrote ./vtk_pred_param/case_286_cmp.vtk
# Wrote ./vtk_pred_param/case_287_cmp.vtk
# Wrote ./vtk_pred_param/case_288_cmp.vtk
# Wrote ./vtk_pred_param/case_289_cmp.vtk
# Wrote ./vtk_pred_param/case_290_cmp.vtk
# Wrote ./vtk_pred_param/case_291_cmp.vtk
# Wrote ./vtk_pred_param/case_292_cmp.vtk
# Wrote ./vtk_pred_param/case_293_cmp.vtk
# Wrote ./vtk_pred_param/case_294_cmp.vtk
# Wrote ./vtk_pred_param/case_295_cmp.vtk
# Wrote ./vtk_pred_param/case_296_cmp.vtk
# Wrote ./vtk_pred_param/case_297_cmp.vtk
# Wrote ./vtk_pred_param/case_298_cmp.vtk
# Wrote ./vtk_pred_param/case_299_cmp.vtk
# Wrote ./vtk_pred_param/case_300_cmp.vtk
# Wrote ./vtk_pred_param/case_301_cmp.vtk
# Wrote ./vtk_pred_param/case_302_cmp.vtk
# Wrote ./vtk_pred_param/case_303_cmp.vtk
# Wrote ./vtk_pred_param/case_304_cmp.vtk
# Wrote ./vtk_pred_param/case_305_cmp.vtk
# Wrote ./vtk_pred_param/case_306_cmp.vtk
# Wrote ./vtk_pred_param/case_307_cmp.vtk
# Wrote ./vtk_pred_param/case_308_cmp.vtk
# Wrote ./vtk_pred_param/case_309_cmp.vtk
# Wrote ./vtk_pred_param/case_311_cmp.vtk
# Wrote ./vtk_pred_param/case_312_cmp.vtk
# Wrote ./vtk_pred_param/case_313_cmp.vtk
# Wrote ./vtk_pred_param/case_314_cmp.vtk
# Wrote ./vtk_pred_param/case_315_cmp.vtk
# Wrote ./vtk_pred_param/case_316_cmp.vtk
# Wrote ./vtk_pred_param/case_317_cmp.vtk
# Wrote ./vtk_pred_param/case_318_cmp.vtk
# Wrote ./vtk_pred_param/case_319_cmp.vtk
# Wrote ./vtk_pred_param/case_320_cmp.vtk
# Wrote ./vtk_pred_param/case_321_cmp.vtk
# Wrote ./vtk_pred_param/case_322_cmp.vtk
# Wrote ./vtk_pred_param/case_323_cmp.vtk
# Wrote ./vtk_pred_param/case_324_cmp.vtk
# Wrote ./vtk_pred_param/case_325_cmp.vtk
# Wrote ./vtk_pred_param/case_326_cmp.vtk
# Wrote ./vtk_pred_param/case_327_cmp.vtk
# Wrote ./vtk_pred_param/case_328_cmp.vtk
# Wrote ./vtk_pred_param/case_329_cmp.vtk
# Wrote ./vtk_pred_param/case_330_cmp.vtk
# Wrote ./vtk_pred_param/case_331_cmp.vtk
# Wrote ./vtk_pred_param/case_332_cmp.vtk
# Wrote ./vtk_pred_param/case_333_cmp.vtk
# Wrote ./vtk_pred_param/case_334_cmp.vtk
# Wrote ./vtk_pred_param/case_337_cmp.vtk
# Wrote ./vtk_pred_param/case_338_cmp.vtk
# Wrote ./vtk_pred_param/case_339_cmp.vtk
# Wrote ./vtk_pred_param/case_340_cmp.vtk
# Wrote ./vtk_pred_param/case_342_cmp.vtk
# Wrote ./vtk_pred_param/case_343_cmp.vtk
# Wrote ./vtk_pred_param/case_345_cmp.vtk
# Wrote ./vtk_pred_param/case_346_cmp.vtk
# Wrote ./vtk_pred_param/case_347_cmp.vtk
# Wrote ./vtk_pred_param/case_348_cmp.vtk
# Wrote ./vtk_pred_param/case_350_cmp.vtk
# Wrote ./vtk_pred_param/case_351_cmp.vtk
# Wrote ./vtk_pred_param/case_352_cmp.vtk
# Wrote ./vtk_pred_param/case_353_cmp.vtk
# Wrote ./vtk_pred_param/case_354_cmp.vtk
# Wrote ./vtk_pred_param/case_355_cmp.vtk
# Wrote ./vtk_pred_param/case_356_cmp.vtk
# Wrote ./vtk_pred_param/case_357_cmp.vtk
# Wrote ./vtk_pred_param/case_358_cmp.vtk
# Wrote ./vtk_pred_param/case_359_cmp.vtk
# Wrote ./vtk_pred_param/case_360_cmp.vtk
# Wrote ./vtk_pred_param/case_361_cmp.vtk
# Wrote ./vtk_pred_param/case_362_cmp.vtk
# Wrote ./vtk_pred_param/case_363_cmp.vtk
# Wrote ./vtk_pred_param/case_364_cmp.vtk
# Wrote ./vtk_pred_param/case_365_cmp.vtk
# Wrote ./vtk_pred_param/case_367_cmp.vtk
# Wrote ./vtk_pred_param/case_368_cmp.vtk
# Wrote ./vtk_pred_param/case_369_cmp.vtk
# Wrote ./vtk_pred_param/case_370_cmp.vtk
# Wrote ./vtk_pred_param/case_371_cmp.vtk
# Wrote ./vtk_pred_param/case_372_cmp.vtk
# Wrote ./vtk_pred_param/case_373_cmp.vtk
# Wrote ./vtk_pred_param/case_374_cmp.vtk
# Wrote ./vtk_pred_param/case_375_cmp.vtk
# Wrote ./vtk_pred_param/case_376_cmp.vtk
# Wrote ./vtk_pred_param/case_377_cmp.vtk
# Wrote ./vtk_pred_param/case_379_cmp.vtk
# Wrote ./vtk_pred_param/case_380_cmp.vtk
# Wrote ./vtk_pred_param/case_381_cmp.vtk
# Wrote ./vtk_pred_param/case_384_cmp.vtk
# Wrote ./vtk_pred_param/case_385_cmp.vtk
# Wrote ./vtk_pred_param/case_386_cmp.vtk
# Wrote ./vtk_pred_param/case_387_cmp.vtk
# Wrote ./vtk_pred_param/case_388_cmp.vtk
# Wrote ./vtk_pred_param/case_391_cmp.vtk
# Wrote ./vtk_pred_param/case_392_cmp.vtk
# Wrote ./vtk_pred_param/case_393_cmp.vtk
# Wrote ./vtk_pred_param/case_394_cmp.vtk
# Wrote ./vtk_pred_param/case_395_cmp.vtk
# Wrote ./vtk_pred_param/case_397_cmp.vtk
# Wrote ./vtk_pred_param/case_398_cmp.vtk
# Wrote ./vtk_pred_param/case_399_cmp.vtk
# Wrote ./vtk_pred_param/case_400_cmp.vtk
# Wrote ./vtk_pred_param/case_401_cmp.vtk
# Wrote ./vtk_pred_param/case_402_cmp.vtk
# Wrote ./vtk_pred_param/case_404_cmp.vtk
# Wrote ./vtk_pred_param/case_405_cmp.vtk
# Wrote ./vtk_pred_param/case_406_cmp.vtk
# Wrote ./vtk_pred_param/case_407_cmp.vtk
# Wrote ./vtk_pred_param/case_408_cmp.vtk
# Wrote ./vtk_pred_param/case_409_cmp.vtk
# Wrote ./vtk_pred_param/case_410_cmp.vtk
# Wrote ./vtk_pred_param/case_411_cmp.vtk
# Wrote ./vtk_pred_param/case_412_cmp.vtk
# Wrote ./vtk_pred_param/case_413_cmp.vtk
# Wrote ./vtk_pred_param/case_414_cmp.vtk
# Wrote ./vtk_pred_param/case_415_cmp.vtk
# Wrote ./vtk_pred_param/case_418_cmp.vtk
# Wrote ./vtk_pred_param/case_419_cmp.vtk
# Wrote ./vtk_pred_param/case_420_cmp.vtk
# Wrote ./vtk_pred_param/case_421_cmp.vtk
# Wrote ./vtk_pred_param/case_422_cmp.vtk
# Wrote ./vtk_pred_param/case_424_cmp.vtk
# Wrote ./vtk_pred_param/case_425_cmp.vtk
# Wrote ./vtk_pred_param/case_426_cmp.vtk
# Wrote ./vtk_pred_param/case_427_cmp.vtk
# Wrote ./vtk_pred_param/case_428_cmp.vtk
# Wrote ./vtk_pred_param/case_429_cmp.vtk
# Wrote ./vtk_pred_param/case_430_cmp.vtk
# Wrote ./vtk_pred_param/case_431_cmp.vtk
# Wrote ./vtk_pred_param/case_432_cmp.vtk
# Wrote ./vtk_pred_param/case_433_cmp.vtk
# Wrote ./vtk_pred_param/case_434_cmp.vtk
# Wrote ./vtk_pred_param/case_435_cmp.vtk
# Wrote ./vtk_pred_param/case_436_cmp.vtk
# Wrote ./vtk_pred_param/case_437_cmp.vtk
# Wrote ./vtk_pred_param/case_438_cmp.vtk
# Wrote ./vtk_pred_param/case_439_cmp.vtk
# Wrote ./vtk_pred_param/case_440_cmp.vtk
# Wrote ./vtk_pred_param/case_441_cmp.vtk
# Wrote ./vtk_pred_param/case_442_cmp.vtk
# Wrote ./vtk_pred_param/case_443_cmp.vtk
# Wrote ./vtk_pred_param/case_444_cmp.vtk
# Wrote ./vtk_pred_param/case_445_cmp.vtk
# Wrote ./vtk_pred_param/case_446_cmp.vtk
# Wrote ./vtk_pred_param/case_447_cmp.vtk
# Wrote ./vtk_pred_param/case_448_cmp.vtk
# Wrote ./vtk_pred_param/case_449_cmp.vtk
# Wrote ./vtk_pred_param/case_450_cmp.vtk
# Wrote ./vtk_pred_param/case_451_cmp.vtk
# Wrote ./vtk_pred_param/case_452_cmp.vtk
# Wrote ./vtk_pred_param/case_453_cmp.vtk
# Wrote ./vtk_pred_param/case_454_cmp.vtk
# Wrote ./vtk_pred_param/case_455_cmp.vtk
# Wrote ./vtk_pred_param/case_456_cmp.vtk
# Wrote ./vtk_pred_param/case_457_cmp.vtk
# Wrote ./vtk_pred_param/case_459_cmp.vtk
# Wrote ./vtk_pred_param/case_460_cmp.vtk
# Wrote ./vtk_pred_param/case_461_cmp.vtk
# Wrote ./vtk_pred_param/case_462_cmp.vtk
# Wrote ./vtk_pred_param/case_464_cmp.vtk
# Wrote ./vtk_pred_param/case_465_cmp.vtk
# Wrote ./vtk_pred_param/case_466_cmp.vtk
# Wrote ./vtk_pred_param/case_467_cmp.vtk
# Wrote ./vtk_pred_param/case_468_cmp.vtk
# Wrote ./vtk_pred_param/case_469_cmp.vtk
# Wrote ./vtk_pred_param/case_470_cmp.vtk
# Wrote ./vtk_pred_param/case_471_cmp.vtk
# Wrote ./vtk_pred_param/case_473_cmp.vtk
# Wrote ./vtk_pred_param/case_475_cmp.vtk
# Wrote ./vtk_pred_param/case_476_cmp.vtk
# Wrote ./vtk_pred_param/case_477_cmp.vtk
# Wrote ./vtk_pred_param/case_478_cmp.vtk
# Wrote ./vtk_pred_param/case_479_cmp.vtk
# Wrote ./vtk_pred_param/case_480_cmp.vtk
# Wrote ./vtk_pred_param/case_482_cmp.vtk
# Wrote ./vtk_pred_param/case_483_cmp.vtk
# Wrote ./vtk_pred_param/case_484_cmp.vtk
# Wrote ./vtk_pred_param/case_485_cmp.vtk
# Wrote ./vtk_pred_param/case_486_cmp.vtk
# Wrote ./vtk_pred_param/case_487_cmp.vtk
# Wrote ./vtk_pred_param/case_488_cmp.vtk
# Wrote ./vtk_pred_param/case_490_cmp.vtk
# Wrote ./vtk_pred_param/case_491_cmp.vtk
# Wrote ./vtk_pred_param/case_492_cmp.vtk
# Wrote ./vtk_pred_param/case_493_cmp.vtk
# Wrote ./vtk_pred_param/case_494_cmp.vtk
# Wrote ./vtk_pred_param/case_495_cmp.vtk
# Wrote ./vtk_pred_param/case_496_cmp.vtk
# Wrote ./vtk_pred_param/case_497_cmp.vtk
# Wrote ./vtk_pred_param/case_498_cmp.vtk
# Wrote ./vtk_pred_param/case_499_cmp.vtk
# Wrote ./vtk_pred_param/case_500_cmp.vtk
# Wrote ./vtk_pred_param/case_501_cmp.vtk
# Wrote ./vtk_pred_param/case_503_cmp.vtk
# Wrote ./vtk_pred_param/case_504_cmp.vtk
# Wrote ./vtk_pred_param/case_505_cmp.vtk
# Wrote ./vtk_pred_param/case_506_cmp.vtk
# Wrote ./vtk_pred_param/case_507_cmp.vtk
# Wrote ./vtk_pred_param/case_508_cmp.vtk
# Wrote ./vtk_pred_param/case_509_cmp.vtk
# Wrote ./vtk_pred_param/case_510_cmp.vtk
# Wrote ./vtk_pred_param/case_513_cmp.vtk
# Wrote ./vtk_pred_param/case_514_cmp.vtk
# Wrote ./vtk_pred_param/case_515_cmp.vtk
# Wrote ./vtk_pred_param/case_516_cmp.vtk
# Wrote ./vtk_pred_param/case_517_cmp.vtk
# Wrote ./vtk_pred_param/case_518_cmp.vtk
# Wrote ./vtk_pred_param/case_519_cmp.vtk
# Wrote ./vtk_pred_param/case_520_cmp.vtk
# Wrote ./vtk_pred_param/case_521_cmp.vtk
# Wrote ./vtk_pred_param/case_522_cmp.vtk
# Wrote ./vtk_pred_param/case_523_cmp.vtk
# Wrote ./vtk_pred_param/case_524_cmp.vtk
# Wrote ./vtk_pred_param/case_525_cmp.vtk
# Wrote ./vtk_pred_param/case_526_cmp.vtk
# Wrote ./vtk_pred_param/case_528_cmp.vtk
# Wrote ./vtk_pred_param/case_529_cmp.vtk
# Wrote ./vtk_pred_param/case_530_cmp.vtk
# Wrote ./vtk_pred_param/case_531_cmp.vtk
# Wrote ./vtk_pred_param/case_532_cmp.vtk
# Wrote ./vtk_pred_param/case_533_cmp.vtk
# Wrote ./vtk_pred_param/case_534_cmp.vtk
# Wrote ./vtk_pred_param/case_535_cmp.vtk
# Wrote ./vtk_pred_param/case_536_cmp.vtk
# Wrote ./vtk_pred_param/case_537_cmp.vtk
# Wrote ./vtk_pred_param/case_538_cmp.vtk
# Wrote ./vtk_pred_param/case_539_cmp.vtk
# Wrote ./vtk_pred_param/case_541_cmp.vtk
# Wrote ./vtk_pred_param/case_542_cmp.vtk
# Wrote ./vtk_pred_param/case_543_cmp.vtk
# Wrote ./vtk_pred_param/case_544_cmp.vtk
# Wrote ./vtk_pred_param/case_545_cmp.vtk
# Wrote ./vtk_pred_param/case_546_cmp.vtk
# Wrote ./vtk_pred_param/case_547_cmp.vtk
# Wrote ./vtk_pred_param/case_548_cmp.vtk
# Wrote ./vtk_pred_param/case_549_cmp.vtk
# Wrote ./vtk_pred_param/case_550_cmp.vtk
# Wrote ./vtk_pred_param/case_551_cmp.vtk
# Wrote ./vtk_pred_param/case_552_cmp.vtk
# Wrote ./vtk_pred_param/case_553_cmp.vtk
# Wrote ./vtk_pred_param/case_554_cmp.vtk
# Wrote ./vtk_pred_param/case_555_cmp.vtk
# Wrote ./vtk_pred_param/case_556_cmp.vtk
# Wrote ./vtk_pred_param/case_557_cmp.vtk
# Wrote ./vtk_pred_param/case_558_cmp.vtk
# Wrote ./vtk_pred_param/case_559_cmp.vtk
# Wrote ./vtk_pred_param/case_560_cmp.vtk
# Wrote ./vtk_pred_param/case_562_cmp.vtk
# Wrote ./vtk_pred_param/case_563_cmp.vtk
# Wrote ./vtk_pred_param/case_564_cmp.vtk
# Wrote ./vtk_pred_param/case_565_cmp.vtk
# Wrote ./vtk_pred_param/case_566_cmp.vtk
# Wrote ./vtk_pred_param/case_567_cmp.vtk
# Wrote ./vtk_pred_param/case_570_cmp.vtk
# Wrote ./vtk_pred_param/case_571_cmp.vtk
# Wrote ./vtk_pred_param/case_572_cmp.vtk
# Wrote ./vtk_pred_param/case_574_cmp.vtk
# Wrote ./vtk_pred_param/case_575_cmp.vtk
# Wrote ./vtk_pred_param/case_576_cmp.vtk
# Wrote ./vtk_pred_param/case_577_cmp.vtk
# Wrote ./vtk_pred_param/case_578_cmp.vtk
# Wrote ./vtk_pred_param/case_580_cmp.vtk
# Wrote ./vtk_pred_param/case_581_cmp.vtk
# Wrote ./vtk_pred_param/case_582_cmp.vtk
# Wrote ./vtk_pred_param/case_583_cmp.vtk
# Wrote ./vtk_pred_param/case_585_cmp.vtk
# Wrote ./vtk_pred_param/case_586_cmp.vtk
# Wrote ./vtk_pred_param/case_588_cmp.vtk
# Wrote ./vtk_pred_param/case_589_cmp.vtk
# Wrote ./vtk_pred_param/case_590_cmp.vtk
# Wrote ./vtk_pred_param/case_591_cmp.vtk
# Wrote ./vtk_pred_param/case_592_cmp.vtk
# Wrote ./vtk_pred_param/case_593_cmp.vtk
# Wrote ./vtk_pred_param/case_594_cmp.vtk
# Wrote ./vtk_pred_param/case_595_cmp.vtk
# Wrote ./vtk_pred_param/case_596_cmp.vtk
# Wrote ./vtk_pred_param/case_598_cmp.vtk
# Wrote ./vtk_pred_param/case_599_cmp.vtk
# Wrote ./vtk_pred_param/case_600_cmp.vtk
# Wrote ./vtk_pred_param/case_601_cmp.vtk
# Wrote ./vtk_pred_param/case_603_cmp.vtk
# Wrote ./vtk_pred_param/case_604_cmp.vtk
# Wrote ./vtk_pred_param/case_605_cmp.vtk
# Wrote ./vtk_pred_param/case_607_cmp.vtk
# Wrote ./vtk_pred_param/case_608_cmp.vtk
# Wrote ./vtk_pred_param/case_609_cmp.vtk
# Wrote ./vtk_pred_param/case_610_cmp.vtk
# Wrote ./vtk_pred_param/case_612_cmp.vtk
# Wrote ./vtk_pred_param/case_613_cmp.vtk
# Wrote ./vtk_pred_param/case_614_cmp.vtk
# Wrote ./vtk_pred_param/case_615_cmp.vtk
# Wrote ./vtk_pred_param/case_616_cmp.vtk
# Wrote ./vtk_pred_param/case_617_cmp.vtk
# Wrote ./vtk_pred_param/case_618_cmp.vtk
# Wrote ./vtk_pred_param/case_619_cmp.vtk
# Wrote ./vtk_pred_param/case_620_cmp.vtk
# Wrote ./vtk_pred_param/case_621_cmp.vtk
# Wrote ./vtk_pred_param/case_622_cmp.vtk
# Wrote ./vtk_pred_param/case_623_cmp.vtk
# Wrote ./vtk_pred_param/case_624_cmp.vtk
# Wrote ./vtk_pred_param/case_625_cmp.vtk
# Wrote ./vtk_pred_param/case_627_cmp.vtk
# Wrote ./vtk_pred_param/case_628_cmp.vtk
# Wrote ./vtk_pred_param/case_629_cmp.vtk
# Wrote ./vtk_pred_param/case_630_cmp.vtk
# Wrote ./vtk_pred_param/case_632_cmp.vtk
# Wrote ./vtk_pred_param/case_633_cmp.vtk
# Wrote ./vtk_pred_param/case_635_cmp.vtk
# Wrote ./vtk_pred_param/case_636_cmp.vtk
# Wrote ./vtk_pred_param/case_637_cmp.vtk
# Wrote ./vtk_pred_param/case_638_cmp.vtk
# Wrote ./vtk_pred_param/case_639_cmp.vtk
# Wrote ./vtk_pred_param/case_641_cmp.vtk
# Wrote ./vtk_pred_param/case_643_cmp.vtk
# Wrote ./vtk_pred_param/case_644_cmp.vtk
# Wrote ./vtk_pred_param/case_646_cmp.vtk
# Wrote ./vtk_pred_param/case_647_cmp.vtk
# Wrote ./vtk_pred_param/case_648_cmp.vtk
# Wrote ./vtk_pred_param/case_649_cmp.vtk
# Wrote ./vtk_pred_param/case_650_cmp.vtk
# Wrote ./vtk_pred_param/case_652_cmp.vtk
# Wrote ./vtk_pred_param/case_653_cmp.vtk
# Wrote ./vtk_pred_param/case_655_cmp.vtk
# Wrote ./vtk_pred_param/case_656_cmp.vtk
# Wrote ./vtk_pred_param/case_657_cmp.vtk
# Wrote ./vtk_pred_param/case_658_cmp.vtk
# Wrote ./vtk_pred_param/case_659_cmp.vtk
# Wrote ./vtk_pred_param/case_661_cmp.vtk
# Wrote ./vtk_pred_param/case_662_cmp.vtk
# Wrote ./vtk_pred_param/case_663_cmp.vtk
# Wrote ./vtk_pred_param/case_664_cmp.vtk
# Wrote ./vtk_pred_param/case_665_cmp.vtk
# Wrote ./vtk_pred_param/case_667_cmp.vtk
# Wrote ./vtk_pred_param/case_668_cmp.vtk
# Wrote ./vtk_pred_param/case_670_cmp.vtk
# Wrote ./vtk_pred_param/case_671_cmp.vtk
# Wrote ./vtk_pred_param/case_672_cmp.vtk
# Wrote ./vtk_pred_param/case_675_cmp.vtk
# Wrote ./vtk_pred_param/case_676_cmp.vtk
# Wrote ./vtk_pred_param/case_677_cmp.vtk
# Wrote ./vtk_pred_param/case_678_cmp.vtk
# Wrote ./vtk_pred_param/case_679_cmp.vtk
# Wrote ./vtk_pred_param/case_680_cmp.vtk
# Wrote ./vtk_pred_param/case_681_cmp.vtk
# Wrote ./vtk_pred_param/case_682_cmp.vtk
# Wrote ./vtk_pred_param/case_683_cmp.vtk
# Wrote ./vtk_pred_param/case_684_cmp.vtk
# Wrote ./vtk_pred_param/case_685_cmp.vtk
# Wrote ./vtk_pred_param/case_686_cmp.vtk
# Wrote ./vtk_pred_param/case_687_cmp.vtk
# Wrote ./vtk_pred_param/case_688_cmp.vtk
# Wrote ./vtk_pred_param/case_689_cmp.vtk
# Wrote ./vtk_pred_param/case_690_cmp.vtk
# Wrote ./vtk_pred_param/case_692_cmp.vtk
# Wrote ./vtk_pred_param/case_693_cmp.vtk
# Wrote ./vtk_pred_param/case_694_cmp.vtk
# Wrote ./vtk_pred_param/case_695_cmp.vtk
# Wrote ./vtk_pred_param/case_698_cmp.vtk
# Wrote ./vtk_pred_param/case_700_cmp.vtk
# Wrote ./vtk_pred_param/case_701_cmp.vtk
# Wrote ./vtk_pred_param/case_703_cmp.vtk
# Wrote ./vtk_pred_param/case_705_cmp.vtk
# Wrote ./vtk_pred_param/case_706_cmp.vtk
# Wrote ./vtk_pred_param/case_707_cmp.vtk
# Wrote ./vtk_pred_param/case_708_cmp.vtk
# Wrote ./vtk_pred_param/case_709_cmp.vtk
# Wrote ./vtk_pred_param/case_710_cmp.vtk
# Wrote ./vtk_pred_param/case_711_cmp.vtk
# Wrote ./vtk_pred_param/case_712_cmp.vtk
# Wrote ./vtk_pred_param/case_713_cmp.vtk
# Wrote ./vtk_pred_param/case_714_cmp.vtk
# Wrote ./vtk_pred_param/case_715_cmp.vtk
# Wrote ./vtk_pred_param/case_716_cmp.vtk
# Wrote ./vtk_pred_param/case_717_cmp.vtk
# Wrote ./vtk_pred_param/case_718_cmp.vtk
# Wrote ./vtk_pred_param/case_719_cmp.vtk
# Wrote ./vtk_pred_param/case_720_cmp.vtk
# Wrote ./vtk_pred_param/case_722_cmp.vtk
# Wrote ./vtk_pred_param/case_723_cmp.vtk
# Wrote ./vtk_pred_param/case_724_cmp.vtk
# Wrote ./vtk_pred_param/case_725_cmp.vtk
# Wrote ./vtk_pred_param/case_726_cmp.vtk
# Wrote ./vtk_pred_param/case_727_cmp.vtk
# Wrote ./vtk_pred_param/case_728_cmp.vtk
# Wrote ./vtk_pred_param/case_729_cmp.vtk
# Wrote ./vtk_pred_param/case_730_cmp.vtk
# Wrote ./vtk_pred_param/case_731_cmp.vtk
# Wrote ./vtk_pred_param/case_732_cmp.vtk
# Wrote ./vtk_pred_param/case_733_cmp.vtk
# Wrote ./vtk_pred_param/case_734_cmp.vtk
# Wrote ./vtk_pred_param/case_735_cmp.vtk
# Wrote ./vtk_pred_param/case_736_cmp.vtk
# Wrote ./vtk_pred_param/case_737_cmp.vtk
# Wrote ./vtk_pred_param/case_739_cmp.vtk
# Wrote ./vtk_pred_param/case_740_cmp.vtk
# Wrote ./vtk_pred_param/case_741_cmp.vtk
# Wrote ./vtk_pred_param/case_742_cmp.vtk
# Wrote ./vtk_pred_param/case_743_cmp.vtk
# Wrote ./vtk_pred_param/case_744_cmp.vtk
# Wrote ./vtk_pred_param/case_745_cmp.vtk
# Wrote ./vtk_pred_param/case_746_cmp.vtk
# Wrote ./vtk_pred_param/case_747_cmp.vtk
# Wrote ./vtk_pred_param/case_749_cmp.vtk
# Wrote ./vtk_pred_param/case_751_cmp.vtk
# Wrote ./vtk_pred_param/case_752_cmp.vtk
# Wrote ./vtk_pred_param/case_753_cmp.vtk
# Wrote ./vtk_pred_param/case_755_cmp.vtk
# Wrote ./vtk_pred_param/case_756_cmp.vtk
# Wrote ./vtk_pred_param/case_757_cmp.vtk
# Wrote ./vtk_pred_param/case_758_cmp.vtk
# Wrote ./vtk_pred_param/case_759_cmp.vtk
# Wrote ./vtk_pred_param/case_760_cmp.vtk
# Wrote ./vtk_pred_param/case_761_cmp.vtk
# Wrote ./vtk_pred_param/case_762_cmp.vtk
# Wrote ./vtk_pred_param/case_764_cmp.vtk
# Wrote ./vtk_pred_param/case_765_cmp.vtk
# Wrote ./vtk_pred_param/case_766_cmp.vtk
# Wrote ./vtk_pred_param/case_767_cmp.vtk
# Wrote ./vtk_pred_param/case_768_cmp.vtk
# Wrote ./vtk_pred_param/case_770_cmp.vtk
# Wrote ./vtk_pred_param/case_771_cmp.vtk
# Wrote ./vtk_pred_param/case_772_cmp.vtk
# Wrote ./vtk_pred_param/case_773_cmp.vtk
# Wrote ./vtk_pred_param/case_774_cmp.vtk
# Wrote ./vtk_pred_param/case_775_cmp.vtk
# Wrote ./vtk_pred_param/case_776_cmp.vtk
# Wrote ./vtk_pred_param/case_777_cmp.vtk
# Wrote ./vtk_pred_param/case_779_cmp.vtk
# Wrote ./vtk_pred_param/case_780_cmp.vtk
# Wrote ./vtk_pred_param/case_781_cmp.vtk
# Wrote ./vtk_pred_param/case_782_cmp.vtk
# Wrote ./vtk_pred_param/case_783_cmp.vtk
# Wrote ./vtk_pred_param/case_785_cmp.vtk
# Wrote ./vtk_pred_param/case_787_cmp.vtk
# Wrote ./vtk_pred_param/case_788_cmp.vtk
# Wrote ./vtk_pred_param/case_789_cmp.vtk
# Wrote ./vtk_pred_param/case_790_cmp.vtk
# Wrote ./vtk_pred_param/case_792_cmp.vtk
# Wrote ./vtk_pred_param/case_793_cmp.vtk
# Wrote ./vtk_pred_param/case_794_cmp.vtk
# Wrote ./vtk_pred_param/case_795_cmp.vtk
# Wrote ./vtk_pred_param/case_796_cmp.vtk
# Wrote ./vtk_pred_param/case_797_cmp.vtk
# Wrote ./vtk_pred_param/case_798_cmp.vtk
# Wrote ./vtk_pred_param/case_800_cmp.vtk
# Wrote ./vtk_pred_param/case_801_cmp.vtk
# Wrote ./vtk_pred_param/case_802_cmp.vtk
# Wrote ./vtk_pred_param/case_803_cmp.vtk
# Wrote ./vtk_pred_param/case_804_cmp.vtk
# Wrote ./vtk_pred_param/case_805_cmp.vtk
# Wrote ./vtk_pred_param/case_806_cmp.vtk
# Wrote ./vtk_pred_param/case_807_cmp.vtk
# Wrote ./vtk_pred_param/case_808_cmp.vtk
# Wrote ./vtk_pred_param/case_809_cmp.vtk
# Wrote ./vtk_pred_param/case_810_cmp.vtk
# Wrote ./vtk_pred_param/case_811_cmp.vtk
# Wrote ./vtk_pred_param/case_812_cmp.vtk
# Wrote ./vtk_pred_param/case_813_cmp.vtk
# Wrote ./vtk_pred_param/case_814_cmp.vtk
# Wrote ./vtk_pred_param/case_815_cmp.vtk
# Wrote ./vtk_pred_param/case_816_cmp.vtk
# Wrote ./vtk_pred_param/case_817_cmp.vtk
# Wrote ./vtk_pred_param/case_818_cmp.vtk
# Wrote ./vtk_pred_param/case_819_cmp.vtk
# Wrote ./vtk_pred_param/case_821_cmp.vtk
# Wrote ./vtk_pred_param/case_822_cmp.vtk
# Wrote ./vtk_pred_param/case_823_cmp.vtk
# Wrote ./vtk_pred_param/case_825_cmp.vtk
# Wrote ./vtk_pred_param/case_827_cmp.vtk
# Wrote ./vtk_pred_param/case_828_cmp.vtk
# Wrote ./vtk_pred_param/case_829_cmp.vtk
# Wrote ./vtk_pred_param/case_830_cmp.vtk
# Wrote ./vtk_pred_param/case_831_cmp.vtk
# Wrote ./vtk_pred_param/case_833_cmp.vtk
# Wrote ./vtk_pred_param/case_834_cmp.vtk
# Wrote ./vtk_pred_param/case_835_cmp.vtk
# Wrote ./vtk_pred_param/case_837_cmp.vtk
# Wrote ./vtk_pred_param/case_839_cmp.vtk
# Wrote ./vtk_pred_param/case_840_cmp.vtk
# Wrote ./vtk_pred_param/case_841_cmp.vtk
# Wrote ./vtk_pred_param/case_842_cmp.vtk
# Wrote ./vtk_pred_param/case_845_cmp.vtk
# Wrote ./vtk_pred_param/case_847_cmp.vtk
# Wrote ./vtk_pred_param/case_848_cmp.vtk
# Wrote ./vtk_pred_param/case_850_cmp.vtk
# Wrote ./vtk_pred_param/case_852_cmp.vtk
# Wrote ./vtk_pred_param/case_853_cmp.vtk
# Wrote ./vtk_pred_param/case_854_cmp.vtk
# Wrote ./vtk_pred_param/case_855_cmp.vtk
# Wrote ./vtk_pred_param/case_856_cmp.vtk
# Wrote ./vtk_pred_param/case_857_cmp.vtk
# Wrote ./vtk_pred_param/case_858_cmp.vtk
# Wrote ./vtk_pred_param/case_859_cmp.vtk
# Wrote ./vtk_pred_param/case_860_cmp.vtk
# Wrote ./vtk_pred_param/case_861_cmp.vtk
# Wrote ./vtk_pred_param/case_862_cmp.vtk
# Wrote ./vtk_pred_param/case_863_cmp.vtk
# Wrote ./vtk_pred_param/case_864_cmp.vtk
# Wrote ./vtk_pred_param/case_865_cmp.vtk
# Wrote ./vtk_pred_param/case_866_cmp.vtk
# Wrote ./vtk_pred_param/case_867_cmp.vtk
# Wrote ./vtk_pred_param/case_868_cmp.vtk
# Wrote ./vtk_pred_param/case_869_cmp.vtk
# Wrote ./vtk_pred_param/case_870_cmp.vtk
# Wrote ./vtk_pred_param/case_871_cmp.vtk
# Wrote ./vtk_pred_param/case_872_cmp.vtk
# Wrote ./vtk_pred_param/case_873_cmp.vtk
# Wrote ./vtk_pred_param/case_874_cmp.vtk
# Wrote ./vtk_pred_param/case_875_cmp.vtk
# Wrote ./vtk_pred_param/case_876_cmp.vtk
# Wrote ./vtk_pred_param/case_877_cmp.vtk
# Wrote ./vtk_pred_param/case_878_cmp.vtk
# Wrote ./vtk_pred_param/case_879_cmp.vtk
# Wrote ./vtk_pred_param/case_880_cmp.vtk
# Wrote ./vtk_pred_param/case_881_cmp.vtk
# Wrote ./vtk_pred_param/case_882_cmp.vtk
# Wrote ./vtk_pred_param/case_884_cmp.vtk
# Wrote ./vtk_pred_param/case_885_cmp.vtk
# Wrote ./vtk_pred_param/case_886_cmp.vtk
# Wrote ./vtk_pred_param/case_887_cmp.vtk
# Wrote ./vtk_pred_param/case_888_cmp.vtk
# Wrote ./vtk_pred_param/case_889_cmp.vtk
# Wrote ./vtk_pred_param/case_890_cmp.vtk
# Wrote ./vtk_pred_param/case_891_cmp.vtk
# Wrote ./vtk_pred_param/case_892_cmp.vtk
# Wrote ./vtk_pred_param/case_893_cmp.vtk
# Wrote ./vtk_pred_param/case_894_cmp.vtk
# Wrote ./vtk_pred_param/case_895_cmp.vtk
# Wrote ./vtk_pred_param/case_896_cmp.vtk
# Wrote ./vtk_pred_param/case_898_cmp.vtk
# Wrote ./vtk_pred_param/case_900_cmp.vtk
# Wrote ./vtk_pred_param/case_901_cmp.vtk
# Wrote ./vtk_pred_param/case_903_cmp.vtk
# Wrote ./vtk_pred_param/case_904_cmp.vtk
# Wrote ./vtk_pred_param/case_905_cmp.vtk
# Wrote ./vtk_pred_param/case_907_cmp.vtk
# Wrote ./vtk_pred_param/case_908_cmp.vtk
# Wrote ./vtk_pred_param/case_909_cmp.vtk
# Wrote ./vtk_pred_param/case_910_cmp.vtk
# Wrote ./vtk_pred_param/case_911_cmp.vtk
# Wrote ./vtk_pred_param/case_912_cmp.vtk
# Wrote ./vtk_pred_param/case_913_cmp.vtk
# Wrote ./vtk_pred_param/case_914_cmp.vtk
# Wrote ./vtk_pred_param/case_915_cmp.vtk
# Wrote ./vtk_pred_param/case_921_cmp.vtk
# Wrote ./vtk_pred_param/case_922_cmp.vtk
# Wrote ./vtk_pred_param/case_923_cmp.vtk
# Wrote ./vtk_pred_param/case_924_cmp.vtk
# Wrote ./vtk_pred_param/case_926_cmp.vtk
# Wrote ./vtk_pred_param/case_927_cmp.vtk
# Wrote ./vtk_pred_param/case_928_cmp.vtk
# Wrote ./vtk_pred_param/case_929_cmp.vtk
# Wrote ./vtk_pred_param/case_930_cmp.vtk
# Wrote ./vtk_pred_param/case_932_cmp.vtk
# Wrote ./vtk_pred_param/case_933_cmp.vtk
# Wrote ./vtk_pred_param/case_934_cmp.vtk
# Wrote ./vtk_pred_param/case_935_cmp.vtk
# Wrote ./vtk_pred_param/case_936_cmp.vtk
# Wrote ./vtk_pred_param/case_937_cmp.vtk
# Wrote ./vtk_pred_param/case_938_cmp.vtk
# Wrote ./vtk_pred_param/case_939_cmp.vtk
# Wrote ./vtk_pred_param/case_941_cmp.vtk
# Wrote ./vtk_pred_param/case_942_cmp.vtk
# Wrote ./vtk_pred_param/case_944_cmp.vtk
# Wrote ./vtk_pred_param/case_946_cmp.vtk
# Wrote ./vtk_pred_param/case_947_cmp.vtk
# Wrote ./vtk_pred_param/case_948_cmp.vtk
# Wrote ./vtk_pred_param/case_949_cmp.vtk
# Wrote ./vtk_pred_param/case_950_cmp.vtk
# Wrote ./vtk_pred_param/case_951_cmp.vtk
# Wrote ./vtk_pred_param/case_952_cmp.vtk
# Wrote ./vtk_pred_param/case_953_cmp.vtk
# Wrote ./vtk_pred_param/case_954_cmp.vtk
# Wrote ./vtk_pred_param/case_956_cmp.vtk
# Wrote ./vtk_pred_param/case_957_cmp.vtk
# Wrote ./vtk_pred_param/case_958_cmp.vtk
# Wrote ./vtk_pred_param/case_960_cmp.vtk
# Wrote ./vtk_pred_param/case_961_cmp.vtk
# Wrote ./vtk_pred_param/case_962_cmp.vtk
# Wrote ./vtk_pred_param/case_963_cmp.vtk
# Wrote ./vtk_pred_param/case_964_cmp.vtk
# Wrote ./vtk_pred_param/case_965_cmp.vtk
# Wrote ./vtk_pred_param/case_966_cmp.vtk
# Wrote ./vtk_pred_param/case_967_cmp.vtk
# Wrote ./vtk_pred_param/case_968_cmp.vtk
# Wrote ./vtk_pred_param/case_969_cmp.vtk
# Wrote ./vtk_pred_param/case_971_cmp.vtk
# Wrote ./vtk_pred_param/case_972_cmp.vtk
# Wrote ./vtk_pred_param/case_973_cmp.vtk
# Wrote ./vtk_pred_param/case_974_cmp.vtk
# Wrote ./vtk_pred_param/case_975_cmp.vtk
# Wrote ./vtk_pred_param/case_976_cmp.vtk
# Wrote ./vtk_pred_param/case_977_cmp.vtk
# Wrote ./vtk_pred_param/case_978_cmp.vtk
# Wrote ./vtk_pred_param/case_979_cmp.vtk
# Wrote ./vtk_pred_param/case_980_cmp.vtk
# Wrote ./vtk_pred_param/case_981_cmp.vtk
# Wrote ./vtk_pred_param/case_982_cmp.vtk
# Wrote ./vtk_pred_param/case_983_cmp.vtk
# Wrote ./vtk_pred_param/case_984_cmp.vtk
# Wrote ./vtk_pred_param/case_985_cmp.vtk
# Wrote ./vtk_pred_param/case_986_cmp.vtk
# Wrote ./vtk_pred_param/case_987_cmp.vtk
# Wrote ./vtk_pred_param/case_988_cmp.vtk
# Wrote ./vtk_pred_param/case_989_cmp.vtk
# Wrote ./vtk_pred_param/case_990_cmp.vtk
# Wrote ./vtk_pred_param/case_991_cmp.vtk
# Wrote ./vtk_pred_param/case_992_cmp.vtk
# Wrote ./vtk_pred_param/case_993_cmp.vtk
# Wrote ./vtk_pred_param/case_995_cmp.vtk
# Wrote ./vtk_pred_param/case_996_cmp.vtk
# Wrote ./vtk_pred_param/case_997_cmp.vtk
# Wrote ./vtk_pred_param/case_998_cmp.vtk
# Wrote ./vtk_pred_param/case_999_cmp.vtk
#
# Done. Comparison VTKs in ./vtk_pred_param

# %%
# 6) Find lowest-error cases (no VTK export)
case_errors = []

for geom_idx, design_item in enumerate(test_ds.design_info):
    for case in design_item:
        pts6   = case['points']
        tgt    = case['coeffs']
        flt_b  = case['flight_cond']  # injected bestpred
        N      = pts6.shape[0]

        # Model prediction with best-predicted shape
        cb = torch.from_numpy(flt_b).float().unsqueeze(0).expand(N, -1).to(device)
        x  = torch.from_numpy(pts6).float().to(device)
        with torch.no_grad(): p_b = model(x, cb).cpu().numpy()

        # Unnormalize predictions and ground truth
        gt_u = unnormalize_coeffs(tgt, test_ds)
        b_u  = unnormalize_coeffs(p_b, test_ds)

        # Compute total L1 error over all points and all 3 coefficients
        err = np.abs(gt_u - b_u)
        total_err = err.mean()
        case_errors.append((case['case_name'], total_err))

# Sort by error and show top 10
case_errors.sort(key=lambda x: x[1])
print("\n=== Top 10 lowest-error cases ===")
for name, err in case_errors[:10]:
    print(f"{name}: Total L1 Error = {err:.6f}")
# Out:
# === Top 10 lowest-error cases ===
# case_717: Total L1 Error = 0.004688
# case_149: Total L1 Error = 0.004694
# case_705: Total L1 Error = 0.004782
# case_143: Total L1 Error = 0.004785
# case_653: Total L1 Error = 0.004804
# case_614: Total L1 Error = 0.004965
# case_562: Total L1 Error = 0.005025
# case_500: Total L1 Error = 0.005049
# case_881: Total L1 Error = 0.005117
# case_459: Total L1 Error = 0.005143
